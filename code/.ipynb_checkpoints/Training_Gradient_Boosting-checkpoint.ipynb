# %% [markdown]
# # Training Gradient Boosting
#
# This notebooks trains gradient boost model based on unigram tfidf vectors of the tasting prescription in order to predict the variety, province and taster name. The aim is less accuracy (or another metric) than evaluating features importance.
#
# As the training takes time, they are all saved in the pickle format to be used later or in the writeup notebook. We also remove the wines without taster names, and set the maximum number of features for the tfidf and bow vectorizer to 300 only. This way, we reduce a bit the time needed for training the gradient boosts.
#
# ## DO NOT RUN THIS FULL NOTEBOOK, it takes a few hours. Go to next chapter to load, evaluate and plot the models

# %%
# IMPORTING THE NECESSARY PACKAGES AND FUNCTIONS:

# generic:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import time 

# more specific:
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import classification_report
import pickle # to save models, for instance LDA outputs

# NLP:
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
# load processed and clean data:
filepath = '../data/winedata_processed_and_tokenized.csv'
winedata = pd.read_csv(filepath).drop('index', axis=1)
print(winedata.shape)
winedata.head().T
# Out:
# (106873, 14)
#                                                                         0  \
# country                                                             Italy
# description             Aromas include tropical fruit, broom, brimston...
# designation                                                  Vulkà Bianco
# points                                                                 87
# price                                                                 NaN
# province                                                Sicily & Sardinia
# region_1                                                             Etna
# region_2                                                              NaN
# taster_name                                                 Kerin O’Keefe
# title                                   Nicosia 2013 Vulkà Bianco  (Etna)
# variety                                                       White Blend
# winery                                                            Nicosia
# tokenized_descriptions  ['aromas', 'include', 'tropical', 'fruit', 'br...
# token_descr_as_string   aromas include tropical fruit broom brimstone ...
#
#                                                                         1  \
# country                                                          Portugal
# description             This is ripe and fruity, a wine that is smooth...
# designation                                                      Avidagos
# points                                                                 87
# price                                                                  15
# province                                                            Douro
# region_1                                                              NaN
# region_2                                                              NaN
# taster_name                                                    Roger Voss
# title                       Quinta dos Avidagos 2011 Avidagos Red (Douro)
# variety                                                    Portuguese Red
# winery                                                Quinta dos Avidagos
# tokenized_descriptions  ['ripe', 'fruity', 'smooth', 'structured', 'fi...
# token_descr_as_string   ripe fruity smooth structured firm tannins fil...
#
#                                                                         2  \
# country                                                                US
# description             Tart and snappy, the flavors of lime flesh and...
# designation                                                           NaN
# points                                                                 87
# price                                                                  14
# province                                                           Oregon
# region_1                                                Willamette Valley
# region_2                                                Willamette Valley
# taster_name                                                  Paul Gregutt
# title                       Rainstorm 2013 Pinot Gris (Willamette Valley)
# variety                                                        Pinot Gris
# winery                                                          Rainstorm
# tokenized_descriptions  ['tart', 'snappy', 'lime', 'flesh', 'rind', 'd...
# token_descr_as_string   tart snappy lime flesh rind dominate green pin...
#
#                                                                         3  \
# country                                                                US
# description             Much like the regular bottling from 2012, this...
# designation                            Vintner's Reserve Wild Child Block
# points                                                                 87
# price                                                                  65
# province                                                           Oregon
# region_1                                                Willamette Valley
# region_2                                                Willamette Valley
# taster_name                                                  Paul Gregutt
# title                   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
# variety                                                        Pinot Noir
# winery                                                       Sweet Cheeks
# tokenized_descriptions  ['like', 'regular', 'bottling', 'comes', 'roug...
# token_descr_as_string   like regular bottling comes rough tannic rusti...
#
#                                                                         4
# country                                                            France
# description             This dry and restrained wine offers spice in p...
# designation                                                           NaN
# points                                                                 87
# price                                                                  24
# province                                                           Alsace
# region_1                                                           Alsace
# region_2                                                              NaN
# taster_name                                                    Roger Voss
# title                               Trimbach 2012 Gewurztraminer (Alsace)
# variety                                                    Gewürztraminer
# winery                                                           Trimbach
# tokenized_descriptions  ['dry', 'restrained', 'offers', 'spice', 'prof...
# token_descr_as_string   dry restrained offers spice profusion balanced...

# %%
# As gradient boosting is quite time consuming, we reduce the size of the dataset.

# To do so, we exclude wines without taster names (and also because we want to predict it)
winedata.dropna(subset=['taster_name'], axis=0, how='any', inplace=True)
winedata.reset_index(inplace=True)

# %%
print(winedata.shape)
winedata.isnull().sum()
# Out:
# (86220, 15)
# index                         0
# country                       0
# description                   0
# designation               24537
# points                        0
# price                      6094
# province                      0
# region_1                   7447
# region_2                  49020
# taster_name                   0
# title                         0
# variety                       0
# winery                        0
# tokenized_descriptions        0
# token_descr_as_string         0
# dtype: int64

# %%
# # greatly reduce the size, just for testing:
# winedata = winedata.head(1000)

# %%
# vectorization using tfidf :
time0 = time.time()

# we only keep only 300 features:
tfidf_vectorizer = TfidfVectorizer(ngram_range=(1,1), # 1-gram
                               max_df=0.95, # ignore t that have a df higher than max_df (corpus-specific stopwords)
                               min_df=10, # ignore terms that have a doc freq lower than threshold.
                               max_features=300, # max number of features
                               use_idf=True,#we definitely want to use inverse document frequencies in our weighting
                               norm=u'l2', #Applies a correction factor so that longer paragraphs and shorter paragraphs get treated equally
                               smooth_idf=True #Adds 1 to all document frequencies, as if an extra document existed that used every word once.  Prevents divide-by-zero errors
                              )
# Applying the vectorizer on the "clean" descriptions:
wine_tfidf = tfidf_vectorizer.fit_transform(winedata.token_descr_as_string)

# list of features
terms = tfidf_vectorizer.get_feature_names()

# store the features in a dataframe:
tf_idf_features = pd.DataFrame(wine_tfidf.toarray(), columns=terms)

# add the different labels that interest us (indexes are the same):
tf_idf_features.loc[:, 'variety'] = winedata['variety']
tf_idf_features.loc[:, 'province'] = winedata['province']
tf_idf_features.loc[:, 'taster_name'] = winedata['taster_name']

print('Done! Vectorization took', time.time()-time0, 'seconds.')
# Out:
# Done! Vectorization took 3.1729578971862793 seconds.

# %%
# vectorization using BoW :
time0 = time.time()

# we only keep only 300 features:
bow_vectorizer = CountVectorizer(ngram_range=(1,1), # 1-gram
                               max_df=0.95, # ignore t that have a df higher than max_df (corpus-specific stopwords)
                               min_df=10, # ignore terms that have a doc freq lower than threshold.
                               max_features=300, # max number of features
                              )
# Applying the vectorizer on the "clean" descriptions:
wine_bow = bow_vectorizer.fit_transform(winedata.token_descr_as_string)

# list of features
terms = bow_vectorizer.get_feature_names()

# store the features in a dataframe:
bow_features = pd.DataFrame(wine_bow.toarray(), columns=terms)

# add the different labels that interest us (indexes are the same):
bow_features.loc[:, 'variety'] = winedata['variety']
bow_features.loc[:, 'province'] = winedata['province']
bow_features.loc[:, 'taster_name'] = winedata['taster_name']

print('Done! Vectorization took', time.time()-time0, 'seconds.')
# Out:
# Done! Vectorization took 1.7131133079528809 seconds.

# %%
# same X, only Y differs
X_tfidf = tf_idf_features.drop(['variety', 'province', 'taster_name'], axis=1)
X_bow = bow_features.drop(['variety', 'province', 'taster_name'], axis=1)

# %% [markdown]
# ## Using tf-idf

# %%
time0 = time.time()

for dep_var in ['variety', 'province', 'taster_name']:
    Y = tf_idf_features[dep_var]
    X_train, X_test, y_train, y_test = train_test_split(X_tfidf, Y, test_size=0.3, random_state=51)
    
    gb = GradientBoostingClassifier() # default parameters (!)
    gb.fit(X_train, y_train) # train

    # Evaluating the model on train set:
    y_pred = gb.predict(X_train)
    print(dep_var, ': ')
    print(classification_report(y_train, y_pred))
    print("")
    
    # save the gb model, so that it can be reloaded later, e.g. for plotting
    pkl_filename = '../data/gradient_boost_predictions/gb_tfidf_'+dep_var+'.pkl'
    with open(pkl_filename, 'wb') as file:
        pickle.dump(gb, file)
    
print('Done! Training took', time.time()-time0, 'seconds.')
# Out:
# variety :
#                             precision    recall  f1-score   support
#
#                   Albariño       0.96      0.75      0.84        93
#                    Barbera       0.78      0.58      0.67       375
#   Bordeaux-style Red Blend       0.56      0.73      0.64      4916
# Bordeaux-style White Blend       0.75      0.49      0.59       835
#             Cabernet Franc       0.90      0.36      0.51       802
#         Cabernet Sauvignon       0.48      0.53      0.50      4269
#                  Carmenère       0.81      0.76      0.78       214
#            Champagne Blend       0.70      0.53      0.60       984
#                 Chardonnay       0.54      0.85      0.66      6129
#               Chenin Blanc       0.91      0.76      0.83       275
#                      Gamay       0.72      0.52      0.60       817
#             Gewürztraminer       0.80      0.62      0.70       624
#                      Glera       0.90      0.95      0.93       230
#                   Grenache       0.89      0.50      0.64       427
#           Grüner Veltliner       0.98      0.90      0.94        62
#                     Malbec       0.53      0.37      0.43      1746
#                     Merlot       0.86      0.23      0.36      1353
#                   Nebbiolo       0.73      0.75      0.74      1628
#               Petite Sirah       0.81      0.64      0.71       372
#               Pinot Grigio       0.86      0.62      0.72       407
#                 Pinot Gris       0.78      0.49      0.60       951
#                 Pinot Noir       0.50      0.73      0.60      7642
#                       Port       0.82      0.66      0.73       476
#             Portuguese Red       0.58      0.43      0.49      1276
#           Portuguese White       0.80      0.57      0.67       473
#                  Red Blend       0.49      0.42      0.45      4641
#      Rhône-style Red Blend       0.79      0.40      0.53      1058
#    Rhône-style White Blend       0.89      0.64      0.74       341
#                   Riesling       0.72      0.70      0.71      2549
#                       Rosé       0.63      0.60      0.62      2338
#                 Sangiovese       0.70      0.46      0.56      1543
#          Sangiovese Grosso       1.00      1.00      1.00         1
#            Sauvignon Blanc       0.58      0.49      0.53      2458
#                     Shiraz       0.82      0.76      0.79       347
#            Sparkling Blend       0.69      0.38      0.49      1101
#                      Syrah       0.53      0.43      0.47      2124
#                Tempranillo       0.54      0.52      0.53      1229
#          Tempranillo Blend       0.77      0.57      0.66       427
#                   Viognier       0.84      0.52      0.65       536
#                White Blend       0.74      0.41      0.53      1001
#                  Zinfandel       0.62      0.38      0.47      1284
#
#                   accuracy                           0.59     60354
#                  macro avg       0.74      0.59      0.64     60354
#               weighted avg       0.61      0.59      0.58     60354
#
#
# province :
#                       precision    recall  f1-score   support
#
#           Alentejano       0.91      0.44      0.59       588
#               Alsace       0.86      0.67      0.75      1636
#           Beaujolais       0.71      0.51      0.60       843
#             Bordeaux       0.61      0.74      0.67      4805
#             Burgundy       0.52      0.56      0.54      3022
#           California       0.68      0.94      0.79     15540
#    Casablanca Valley       0.83      0.57      0.67       434
#            Catalonia       0.70      0.50      0.58       746
#            Champagne       0.73      0.63      0.68      1201
#     Colchagua Valley       0.86      0.46      0.60       560
#                Douro       0.74      0.35      0.47       940
#         France Other       0.92      0.56      0.69       434
# Languedoc-Roussillon       0.84      0.69      0.76       347
#         Loire Valley       0.59      0.41      0.49      1184
#         Maipo Valley       0.84      0.56      0.67       438
#          Marlborough       0.84      0.59      0.69       548
#     Mendoza Province       0.62      0.55      0.58      2077
#                Mosel       0.76      0.70      0.73       781
#             New York       0.72      0.47      0.57      1675
#   Northeastern Italy       0.85      0.72      0.78       459
#       Northern Spain       0.64      0.52      0.58      1857
#               Oregon       0.63      0.55      0.59      4091
#             Piedmont       0.79      0.67      0.72      1860
#                 Port       0.85      0.67      0.75       448
#             Provence       0.64      0.60      0.62       880
#         Rhône Valley       0.76      0.52      0.62       953
#    Sicily & Sardinia       0.89      0.66      0.76       305
#      South Australia       0.77      0.52      0.62       839
#     Southwest France       0.80      0.33      0.47       823
#                 Tejo       0.85      0.56      0.68       390
#              Tuscany       0.74      0.79      0.76      2766
#               Veneto       0.83      0.55      0.66       699
#             Virginia       0.90      0.75      0.82       256
#           Washington       0.73      0.64      0.68      5929
#
#             accuracy                           0.69     60354
#            macro avg       0.76      0.59      0.65     60354
#         weighted avg       0.70      0.69      0.68     60354
#
#
# taster_name :
#                     precision    recall  f1-score   support
#
# Alexander Peartree       0.93      0.80      0.86       227
# Anna Lee C. Iijima       0.85      0.72      0.78      2486
#   Anne Krebiehl MW       0.94      0.89      0.91      1110
#       Carrie Dykes       0.94      0.79      0.86       136
#  Christina Pickard       0.96      0.74      0.84       286
#         Jim Gordon       0.85      0.79      0.82      3308
#     Joe Czerwinski       0.81      0.58      0.67      1942
#      Kerin O’Keefe       0.95      0.94      0.95      5926
#      Lauren Buzzeo       0.89      0.75      0.82       426
#      Matt Kettmann       0.88      0.89      0.88      4890
#  Michael Schachner       0.84      0.85      0.84      6207
#       Paul Gregutt       0.75      0.78      0.76      6552
#         Roger Voss       0.92      0.96      0.94     15968
#   Sean P. Sullivan       0.85      0.86      0.85      3528
#    Susan Kostrzewa       0.90      0.85      0.88       112
#     Virginie Boone       0.76      0.78      0.77      7250
#
#           accuracy                           0.86     60354
#          macro avg       0.88      0.81      0.84     60354
#       weighted avg       0.86      0.86      0.86     60354
#
#
# Done! Training took 3154.8975369930267 seconds.

# %% [markdown]
# ## Using Bag of Words

# %%
time0 = time.time()

for dep_var in ['variety', 'province', 'taster_name']:
    Y = bow_features[dep_var]
    X_train, X_test, y_train, y_test = train_test_split(X_bow, Y, test_size=0.3, random_state=51)
    
    gb = GradientBoostingClassifier() # default parameters (!)
    gb.fit(X_train, y_train) # train

    # Evaluating the model on train set:
    y_pred = gb.predict(X_train)
    print(dep_var, ': ')
    print(classification_report(y_train, y_pred))
    print("")
    
    # save the gb model, so that it can be reloaded later, e.g. for plotting
    pkl_filename = '../data/gradient_boost_predictions/gb_bow_'+dep_var+'.pkl'
    with open(pkl_filename, 'wb') as file:
        pickle.dump(gb, file)
    
print('Done! Training took', time.time()-time0, 'seconds.')
# Out:
# variety :
#                             precision    recall  f1-score   support
#
#                   Albariño       0.56      0.42      0.48        93
#                    Barbera       0.79      0.34      0.48       375
#   Bordeaux-style Red Blend       0.52      0.72      0.60      4916
# Bordeaux-style White Blend       0.62      0.34      0.44       835
#             Cabernet Franc       0.82      0.19      0.31       802
#         Cabernet Sauvignon       0.44      0.50      0.47      4269
#                  Carmenère       0.47      0.27      0.34       214
#            Champagne Blend       0.61      0.44      0.51       984
#                 Chardonnay       0.50      0.82      0.62      6129
#               Chenin Blanc       0.69      0.40      0.51       275
#                      Gamay       0.59      0.37      0.45       817
#             Gewürztraminer       0.70      0.50      0.58       624
#                      Glera       0.83      0.82      0.82       230
#                   Grenache       0.76      0.32      0.45       427
#           Grüner Veltliner       0.71      0.55      0.62        62
#                     Malbec       0.46      0.33      0.38      1746
#                     Merlot       0.80      0.11      0.19      1353
#                   Nebbiolo       0.69      0.71      0.70      1628
#               Petite Sirah       0.68      0.34      0.46       372
#               Pinot Grigio       0.74      0.37      0.50       407
#                 Pinot Gris       0.68      0.32      0.43       951
#                 Pinot Noir       0.46      0.73      0.56      7642
#                       Port       0.73      0.51      0.60       476
#             Portuguese Red       0.53      0.34      0.41      1276
#           Portuguese White       0.60      0.36      0.45       473
#                  Red Blend       0.44      0.40      0.42      4641
#      Rhône-style Red Blend       0.67      0.28      0.40      1058
#    Rhône-style White Blend       0.74      0.40      0.52       341
#                   Riesling       0.69      0.67      0.68      2549
#                       Rosé       0.62      0.57      0.59      2338
#                 Sangiovese       0.64      0.39      0.49      1543
#          Sangiovese Grosso       0.25      1.00      0.40         1
#            Sauvignon Blanc       0.50      0.44      0.47      2458
#                     Shiraz       0.71      0.60      0.65       347
#            Sparkling Blend       0.61      0.30      0.40      1101
#                      Syrah       0.48      0.38      0.42      2124
#                Tempranillo       0.47      0.41      0.44      1229
#          Tempranillo Blend       0.63      0.35      0.45       427
#                   Viognier       0.67      0.33      0.44       536
#                White Blend       0.60      0.26      0.37      1001
#                  Zinfandel       0.49      0.31      0.38      1284
#
#                   accuracy                           0.52     60354
#                  macro avg       0.61      0.44      0.49     60354
#               weighted avg       0.55      0.52      0.51     60354
#
#
# province :
#                       precision    recall  f1-score   support
#
#           Alentejano       0.80      0.23      0.35       588
#               Alsace       0.84      0.65      0.73      1636
#           Beaujolais       0.61      0.38      0.47       843
#             Bordeaux       0.55      0.73      0.63      4805
#             Burgundy       0.47      0.52      0.50      3022
#           California       0.64      0.94      0.76     15540
#    Casablanca Valley       0.72      0.42      0.53       434
#            Catalonia       0.58      0.36      0.45       746
#            Champagne       0.68      0.57      0.62      1201
#     Colchagua Valley       0.79      0.34      0.47       560
#                Douro       0.64      0.23      0.34       940
#         France Other       0.73      0.22      0.34       434
# Languedoc-Roussillon       0.84      0.64      0.72       347
#         Loire Valley       0.49      0.31      0.38      1184
#         Maipo Valley       0.73      0.37      0.49       438
#          Marlborough       0.74      0.41      0.53       548
#     Mendoza Province       0.55      0.51      0.53      2077
#                Mosel       0.70      0.62      0.66       781
#             New York       0.68      0.40      0.50      1675
#   Northeastern Italy       0.75      0.61      0.67       459
#       Northern Spain       0.58      0.46      0.51      1857
#               Oregon       0.60      0.55      0.57      4091
#             Piedmont       0.74      0.60      0.67      1860
#                 Port       0.74      0.49      0.59       448
#             Provence       0.54      0.49      0.52       880
#         Rhône Valley       0.66      0.42      0.51       953
#    Sicily & Sardinia       0.73      0.40      0.52       305
#      South Australia       0.73      0.44      0.54       839
#     Southwest France       0.71      0.18      0.29       823
#                 Tejo       0.70      0.21      0.32       390
#              Tuscany       0.70      0.76      0.73      2766
#               Veneto       0.78      0.44      0.56       699
#             Virginia       0.86      0.44      0.58       256
#           Washington       0.71      0.62      0.66      5929
#
#             accuracy                           0.64     60354
#            macro avg       0.69      0.47      0.54     60354
#         weighted avg       0.65      0.64      0.62     60354
#
#
# taster_name :
#                     precision    recall  f1-score   support
#
# Alexander Peartree       0.87      0.63      0.73       227
# Anna Lee C. Iijima       0.83      0.70      0.76      2486
#   Anne Krebiehl MW       0.92      0.87      0.90      1110
#       Carrie Dykes       0.91      0.63      0.75       136
#  Christina Pickard       0.90      0.55      0.69       286
#         Jim Gordon       0.85      0.78      0.81      3308
#     Joe Czerwinski       0.80      0.55      0.65      1942
#      Kerin O’Keefe       0.95      0.94      0.94      5926
#      Lauren Buzzeo       0.83      0.60      0.70       426
#      Matt Kettmann       0.86      0.88      0.87      4890
#  Michael Schachner       0.83      0.85      0.84      6207
#       Paul Gregutt       0.73      0.77      0.75      6552
#         Roger Voss       0.91      0.96      0.94     15968
#   Sean P. Sullivan       0.85      0.85      0.85      3528
#    Susan Kostrzewa       0.95      0.79      0.86       112
#     Virginie Boone       0.74      0.78      0.76      7250
#
#           accuracy                           0.85     60354
#          macro avg       0.86      0.76      0.80     60354
#       weighted avg       0.85      0.85      0.85     60354
#
#
# Done! Training took 8381.054848194122 seconds.

# %% [markdown]
# ## Evaluation
#
# **Some observations:**
#
# * We keep in mind that the classes are highly imbalanced in the 3 cases.
# * The gradient boosting performed better for predicting the taster name, but it might just be that the baseline performance is higher due to the lower number of features.
# * The classifier performed better when using the tf-idf features than the BoW count vectors.
#
# ### The most important features
#
# #### Variety
# We first have a look at all the tf-idf features used to predict variety and their relative importance in the model.

# %%
# Load the previously trained gradient boost model:
pkl_filename = "../data/gradient_boost_predictions/gb_tfidf_variety.pkl"
with open(pkl_filename, 'rb') as file:
    gb = pickle.load(file)

feature_importance = gb.feature_importances_

# Make importances relative to max importance.
feature_importance = 100.0 * (feature_importance / feature_importance.max())
    
sorted_idx = np.argsort(feature_importance) # used to sort the features in the plot
pos = np.arange(sorted_idx.shape[0]) + .5

plt.figure(figsize=(10,60), dpi=200)
# plt.figure(num=None, figsize=(4, 4), dpi=200, facecolor='w')
plt.barh(pos, feature_importance[sorted_idx], align='center', color='steelblue')
plt.yticks(pos, X_tfidf.columns[sorted_idx])
plt.xlabel('Relative Importance')
plt.title('Variable Importance')
plt.show()

# %% [markdown]
# We note that some words are more useful than other to predict the wine wariety. Some precise taste descriptors are among the top words, like "tannins", "apple", "cherry". Some words are probably more used as n-gram like "alongside", "palate". At the bottom of the list, there are some words that are less useful to predict variety and that are more generic, like "subtle", "integrated", "sip", "flavor", "textured".
#
# #### Province

# %%
# Load the previously trained gradient boost model:
pkl_filename = "../data/gradient_boost_predictions/gb_tfidf_province.pkl"
with open(pkl_filename, 'rb') as file:
    gb = pickle.load(file)

feature_importance = gb.feature_importances_

# Make importances relative to max importance.
feature_importance = 100.0 * (feature_importance / feature_importance.max())
    
sorted_idx = np.argsort(feature_importance) # used to sort the features in the plot
pos = np.arange(sorted_idx.shape[0]) + .5

plt.figure(figsize=(10,60), dpi=200)
# plt.figure(num=None, figsize=(4, 4), dpi=200, facecolor='w')
plt.barh(pos, feature_importance[sorted_idx], align='center', color='steelblue')
plt.yticks(pos, X_tfidf.columns[sorted_idx])
plt.xlabel('Relative Importance')
plt.title('Variable Importance')
plt.show()

# %% [markdown]
# The results are a bit different. Most of the features describing the taste are now in the middle. Except for "tannins" for instance. The 2 top features are "drink" and "aromas" and it is not obvious why they are the most useful to predict the province...
#
# #### Taster Name

# %%
# Load the previously trained gradient boost model:
pkl_filename = "../data/gradient_boost_predictions/gb_tfidf_taster_name.pkl"
with open(pkl_filename, 'rb') as file:
    gb = pickle.load(file)

feature_importance = gb.feature_importances_

# Make importances relative to max importance.
feature_importance = 100.0 * (feature_importance / feature_importance.max())
    
sorted_idx = np.argsort(feature_importance) # used to sort the features in the plot
pos = np.arange(sorted_idx.shape[0]) + .5

plt.figure(figsize=(10,60), dpi=200)
# plt.figure(num=None, figsize=(4, 4), dpi=200, facecolor='w')
plt.barh(pos, feature_importance[sorted_idx], align='center', color='steelblue')
plt.yticks(pos, X_tfidf.columns[sorted_idx])
plt.xlabel('Relative Importance')
plt.title('Variable Importance')
plt.show()

# %% [markdown]
# Note that we do not know if those words are the best features to predict the taster names because they use a different vocabular or because they tasted wines with different tastes, because for instance they come from a different region or province.

# %% [markdown]
# ### Plots the top features of each cases

# %%
models_to_plot = ['gb_tfidf_variety.pkl', 'gb_tfidf_province.pkl', 
                  'gb_tfidf_taster_name.pkl', 'gb_bow_variety.pkl', 
                  'gb_bow_province.pkl', 'gb_bow_taster_name.pkl']
plot_titles = ['top 10 tf-idf features to classify variety', 
               'top 10 tf-idf features to classify province',
               'top 10 tf-idf features to classify taster', 
               'top 10 BoW features to classify variety',
               'top 10 BoW features to classify province', 
               'top 10 BoW features to classify taster']

fig, axs = plt.subplots(2,3, figsize=(15, 10), facecolor='w', dpi=200)

axs = axs.ravel()

top_n = 10 # number of features to plot:

for i, model in enumerate(models_to_plot):
    pkl_filename = "../data/gradient_boost_predictions/" + model
    with open(pkl_filename, 'rb') as file:
        gb = pickle.load(file)
        
    feature_importance = gb.feature_importances_
    feature_importance = 100.0 * (feature_importance / feature_importance.max())
    sorted_idx = np.argsort(feature_importance) # used to sort the features in the plot
    pos = np.arange(sorted_idx.shape[0]) + .5
    pos = pos[-top_n:]
    
    axs[i].barh(pos, feature_importance[sorted_idx][-top_n:], align='center', color='steelblue')
    axs[i].set_title(plot_titles[i])
    axs[i].set_yticks(pos)
    axs[i].set_yticklabels(list(X_tfidf.columns[sorted_idx][-top_n:]))
    axs[i].set_xlabel('Relative Importance')
    
    axs[i].spines['top'].set_visible(False) # for the style, remove frame
    axs[i].spines['right'].set_visible(False)

    plt.tight_layout(pad=1.08, h_pad=None, w_pad=None, rect=None)

plt.savefig("../figures/top_10_features_GB.png")

# %% [markdown]
# ## To Do:
#
# Test generalization on the test set:
